# %% [markdown]
# Downloading ffmpeg-python and pytube

# %%
# !pip install ffmpeg-python
# !pip install pytube
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (0.18.3)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %% [markdown]
# Importing necessary pachages

# %%
import os
import ffmpeg
import shutil
import sys
import pytube
from multiprocessing import Pool
from PIL import Image
import time
import io

# %% [markdown]
# Preparing Directories

# %%
os.getcwd()
# Out:
# '/content'

# %%
def prepare_dirs():
  '''Prepare directories for ffmpeg-assignment
  First it takes the mounted drive and akes a base directory called ffmpeg_assignment
  Then it creates input and output directories
  the tree is like:
  - base_directory:
    - inputs
    - outputs:
      - all_outputs
      - logs
      - samples
  '''
  drive_directory = os.path.abspath('/content')
  # creating base dir
  os.makedirs(os.path.join(drive_directory,'ffmpeg_assignment'),exist_ok=True)
  base_directory = os.path.abspath(os.path.join(drive_directory,'ffmpeg_assignment'))
  # creating input/output dirs
  os.makedirs(os.path.join(base_directory,'inputs'),exist_ok=True)
  os.makedirs(os.path.join(base_directory,'outputs'),exist_ok=True)
  input_directory = os.path.abspath(os.path.join(base_directory,'inputs'))
  output_directory = os.path.abspath(os.path.join(base_directory,'outputs'))
  # Creating all_outputs, logs and samples directories
  os.makedirs(os.path.join(output_directory,'all_outputs'),exist_ok=True)
  os.makedirs(os.path.join(output_directory,'samples'),exist_ok=True)
  os.makedirs(os.path.join(output_directory,'logs'),exist_ok=True)
  all_outputs_directory = os.path.abspath(os.path.join(output_directory,'all_outputs'))
  samples_directory = os.path.abspath(os.path.join(output_directory,'samples'))
  logs_directory = os.path.abspath(os.path.join(output_directory,'logs'))
  return input_directory, output_directory, all_outputs_directory, logs_directory, samples_directory

# %%
def download_video(url,path):
  '''This function downloads the video from the given youtube url and saves it in the given path
  Params:
  - url: the url of the youtube video
  - path: the path where the video will be saved
  '''
  yt = pytube.YouTube(url)
  yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download(path)

# %%
# Creating The directories
inputs_dir, output_dir, all_outputs_dir, logs_dir, samples_dir = prepare_dirs()

# %%
# Downloading From Youtube
download_video('https://youtu.be/WCjLd7QAJq8?si=0pQsRSmrYl8XzKM_',inputs_dir)

# %%
# Getting Video Propeties
probes = ffmpeg.probe(os.path.join(inputs_dir,'3 Hour Timer.mp4'))

# %%
# Video Durtion
duration = float(probes.get('streams')[0].get('duration'))
duration
# Out:
# 10809.0

# %%
def divide_video(segments):
  '''This function divides the video into segments and saves them in the given path
  Params:
  - path: the path where the video will be saved
  - segments: the number of segments to divide the video into
  '''
  try:
    path = os.path.abspath(os.path.join(inputs_dir,list(filter(lambda x: x.endswith('.mp4'),os.listdir(inputs_dir)))[0]))
    probes  = ffmpeg.probe(path)
    print(f'Dividing video into {segments} segments')
    duration = float(probes.get('streams')[0].get('duration'))
    segment_duration = duration/segments
    sgmts = [segment_duration*y for y in range(segments)]
    print(sgmts)
    os.makedirs(os.path.join(inputs_dir,'vodeo_segments'),exist_ok=True)
    for i,s in enumerate(sgmts):
      ffmpeg.input(path, ss=s,t=segment_duration).output(os.path.join(os.path.join(inputs_dir,'vodeo_segments'),f'part_{i+1}.mp4')).run()
  except Exception as e:
    with open(os.path.join(logs_dir,'segments_logs.txt'),'a') as f:
      f.write(f'Error: {e} has occured at {time.time()}\n')

  return os.listdir(os.path.join(inputs_dir,'vodeo_segments'))

# %%
divide_video(3)
# Out:
# Dividing video into 3 segments
# [0.0, 3603.0, 7206.0]
# ['part_2.mp4', 'part_1.mp4', 'part_3.mp4']

# %%
def extract_images(vid):
  '''This function extracts images from the given video and saves them in the given path
  Params:
  - path: the path where the images will be saved
  '''
  try:
     print('Starting...........')
     os.makedirs(os.path.join(all_outputs_dir,'all_images'),exist_ok=True)
     all_images_path = os.path.join(all_outputs_dir,'all_images')
     path = os.path.abspath(os.path.join(inputs_dir,'vodeo_segments',vid))
     probes  = ffmpeg.probe(path)
     duration = float(probes.get('streams')[0].get('duration'))
     fps = int(probes.get('streams')[0].get('r_frame_rate').split('/')[0])
     all_frames = int(probes.get('streams')[0].get('nb_frames'))
     frame_interval = duration / fps
     frame_times = [i for i in range(int(duration))]
     for frm in frame_times:
      out,_ = (ffmpeg.input(path,ss=frm).output('pipe:', format='image2', vframes=1,vcodec='png').run(capture_stdout=True,capture_stderr=True))
      print('Saving Image....')
      img= Image.open(io.BytesIO(out))
      img.save(os.path.join(all_images_path,f'{vid}_image_{frm}.png'))
      print(f'Image saved at {os.path.join(all_images_path,f"{vid}_image_{frm}.png")}')
  except Exception as e:
    with open(os.path.join(logs_dir,'images_logs.txt'),'a') as f:
      f.write(f'Error: {e} has occured at {time.time()}\n')

# %%
video_segments = os.listdir(os.path.join(inputs_dir,'vodeo_segments'))
with Pool(10) as p:
  p.map(extract_images,video_segments)
# Out:
# Streaming output truncated to the last 5000 lines.
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2772.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2748.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2773.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2789.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2749.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2774.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2750.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2790.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2751.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2775.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2752.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2791.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2776.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2753.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2792.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2754.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2793.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2777.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2755.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2794.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2756.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2778.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2795.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2757.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2796.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2779.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2758.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2797.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2759.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2798.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2780.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2799.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2760.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2781.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2800.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2761.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2801.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2762.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2782.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2802.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2763.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2803.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2783.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2764.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2804.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2784.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2765.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2805.png
# Saving Image....
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2766.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2785.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2806.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2767.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2807.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2786.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2808.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2768.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2787.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2769.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2809.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2810.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2770.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2788.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2811.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2771.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2789.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2812.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2772.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2790.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2813.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2773.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2814.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2791.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2774.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2792.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2815.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2775.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2793.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2816.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2794.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2776.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2817.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2795.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2796.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2777.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2818.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2797.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2778.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2819.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2798.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2779.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2799.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2820.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2800.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2780.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2801.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2821.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2781.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2802.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2822.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2803.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2782.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2804.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2823.png
#
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2783.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2805.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2824.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2806.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2784.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2825.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2807.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2785.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2808.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2826.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2809.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2786.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2827.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2810.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2828.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2787.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2811.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2829.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2812.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2788.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2813.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2830.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2789.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2814.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2831.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2790.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2815.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2832.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2791.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2816.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2833.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2792.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2834.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2817.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2793.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2835.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2794.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2818.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2836.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2795.png
# Saving Image....
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2837.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2819.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2796.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2838.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2797.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2820.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2839.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2798.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2840.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2821.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2799.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2841.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2800.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2822.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2842.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2801.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2843.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2823.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2802.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2844.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2824.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2803.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2845.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2804.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2846.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2825.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2805.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2847.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2806.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2826.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2848.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2807.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2827.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2849.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2808.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2850.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2828.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2809.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2851.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2810.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2829.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2852.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2811.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2830.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2853.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2812.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2854.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2831.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2813.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2855.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2832.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2814.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2856.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2833.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2815.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2857.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2834.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2816.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2835.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2858.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2836.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2817.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2837.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2859.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2838.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2818.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2839.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2860.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2819.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2840.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2861.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2841.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2820.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2842.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2862.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2821.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2843.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2863.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2844.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2822.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2864.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2845.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2823.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2846.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2865.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2847.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2824.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2866.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2848.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2825.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2867.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2849.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2826.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2850.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2868.png
# Saving Image....
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2851.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2827.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2869.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2852.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2828.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2870.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2853.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2829.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2871.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2854.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2830.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2855.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2872.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2856.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2831.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2873.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2857.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2832.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2874.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2858.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2875.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2833.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2859.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2876.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2834.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2877.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2835.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2860.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2878.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2836.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2879.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2861.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2837.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2838.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2880.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2862.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2839.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2881.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2840.pngSaving Image....
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2863.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2882.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2841.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2883.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2864.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2842.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2884.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2865.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2843.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2885.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2844.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2886.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2866.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2845.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2887.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2846.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2867.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2888.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2847.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2889.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2868.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2848.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2890.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2869.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2849.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2891.png
# Saving Image....
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2850.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2870.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2892.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2851.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2893.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2871.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2894.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2852.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2872.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2853.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2895.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2854.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2896.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2873.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2855.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2897.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2874.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2898.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2875.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2856.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2876.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2899.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2857.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2877.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2878.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2900.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2858.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2879.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2880.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2901.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2859.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2881.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2902.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2860.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2882.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2903.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2883.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2861.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2884.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2904.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2862.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2885.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2905.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2886.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2863.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2906.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2887.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2864.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2888.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2907.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2865.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2889.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2908.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2866.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2890.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2909.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2891.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2867.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2892.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2910.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2868.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2893.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2911.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2869.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2894.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2912.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2895.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2870.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2896.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2913.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2871.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2897.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2914.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2872.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2898.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2915.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2873.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2899.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2900.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2916.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2874.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2917.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2875.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2901.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2918.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2876.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2919.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2902.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2877.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2920.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2878.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2921.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2903.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2879.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2922.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2904.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2880.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2923.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2881.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2924.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2905.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2882.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2925.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2906.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2883.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2926.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2884.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_2907.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_2927.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_2885.png
# Saving Image....
# ...
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3558.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3533.png
#
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3580.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3559.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3534.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3560.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3581.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3535.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3561.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3582.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3562.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3536.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3583.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3563.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3537.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3584.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3564.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3585.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3538.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3586.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3565.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3587.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3539.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3566.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3588.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3540.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3589.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3567.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3590.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3541.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3568.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3542.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3591.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3543.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3569.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3592.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3544.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3593.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3570.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3545.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3594.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3546.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3571.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3595.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3547.png
# Saving Image....
# Saving Image....Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3596.png
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3572.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3548.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3549.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3597.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3573.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3598.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3550.png
# Saving Image....
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3574.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3599.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3551.png
#
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3552.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3600.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3575.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3553.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3601.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3576.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3554.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_3.mp4_image_3602.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3577.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3555.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3556.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3578.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3557.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3579.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3558.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3559.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3580.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3560.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3581.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3561.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3562.pngSaving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3582.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3563.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3583.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3584.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3564.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3585.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3565.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3586.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3587.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3566.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3588.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3589.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3567.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3590.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3568.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3591.png
# Saving Image....
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3569.png
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3592.png
# Saving Image....Saving Image....
#
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3593.pngImage saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3570.png
#
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3594.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3571.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3595.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3572.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3596.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3573.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3597.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3598.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3574.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3599.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3600.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3575.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3601.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_2.mp4_image_3602.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3576.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3577.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3578.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3579.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3580.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3581.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3582.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3583.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3584.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3585.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3586.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3587.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3588.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3589.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3590.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3591.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3592.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3593.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3594.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3595.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3596.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3597.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3598.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3599.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3600.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3601.png
# Saving Image....
# Image saved at /content/ffmpeg_assignment/outputs/all_outputs/all_images/part_1.mp4_image_3602.png

# %%
def get_samples(source_path,target_path,n):
  '''This function gets the samples from the given images and saves them in the given path
  Params:
  - source_path: the path where the samples will be taken from
  - target_path: the path where the samples will be saved
  - n how many samples to take
  '''
  path = os.path.abspath(source_path)
  data = os.listdir(path)
  for i in range(s):
    if i%n == 0:
      shutil.copy(os.path.join(path,data[i]),target_path)
      print(f'Copied {i} samples')

# %%
images = os.path.abspath(os.path.join(all_outputs_dir,'all_images'))
samples = os.path.abspath(os.path.join(samples_dir))
get_samples(images,samples,50)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
shutil.rmtree('/content/drive/MyDrive/ffmpeg_assignment')
shutil.copytree('/content/ffmpeg_assignment', '/content/drive/MyDrive/ffmpeg_assignment')
# Out:
# '/content/drive/MyDrive/ffmpeg_assignment'

# %%
len(os.listdir(samples_dir))
# Out:
# 10809
